# %%
import sys

sys.path.append('..')

# %matplotlib notebook
from edge_frequency_analysis import EdgeFrequencyAnalysis

im7 = EdgeFrequencyAnalysis("../images/20200522_213922.jpg")
im7.crop(2100, 1400, 128, 128)
im7.analyze()
im7.list_maximums(80)
# Out:
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
#     0     6  1.968 4.107627292466286
#     0    -6  1.968 4.719951285817277
#     1     8  1.228 1.9743630584595815
#     0     4  0.998 3.640549504271966
#     0    -4  0.998 4.628152750960169
#     1    -7  0.982 2.354568196046527
#     6     0  0.929 1.2750396081895232
#    -6     0  0.929 2.1252556596397723
#     6     6  0.835 1.7020908862382045
#    -4     1  0.753 2.6667816483032785
#     1     4  0.752 1.3129622389280222
#     0   -10  0.690 1.3767519013809237
#     0    10  0.690 1.985301446125903
#     2     6  0.665 1.8029811785635506
#     2    -8  0.622 1.7004963197653185
#     1    12  0.604 1.2832955362734415
#     1     6  0.595 1.615743725340305
#    -4     0  0.593 1.3326169626474123
#     4     0  0.593 1.4347325059756306
#     0    12  0.584 1.3686397884970618
#     0   -12  0.584 1.2611938206794058
#     2    -7  0.583 2.2255033951561556
# ...
