# %%
import sys

sys.path.append('..')

# %matplotlib notebook
from edge_frequency_analysis import EdgeFrequencyAnalysis

im5 = EdgeFrequencyAnalysis("../images/20200525_003805.jpg")
im5.crop(800, 800, 1280, 1280)
im5.analyze()
im5.analyze_slopes()
im5.list_maximums(40)
# Out:
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="640">
#    51    51  0.932 2.371321610115188
#    51    50  0.813 1.486539565298837
#     5     4  0.601 1.354273250650033
#     4     5  0.525 1.626848552386806
#   -51    51  0.507 0.809698150657846
#    51   -51  0.507 1.2733538357582117
#   -52    51  0.476 1.7103183619022382
#    52    51  0.460 0.9737760061548704
#   102   101  0.403 0.6808362904199327
#    14   -25  0.388 0.6190479229185157
# Sorted by metric
#    14   -25  0.388 0.6190479229185157
#   102   101  0.403 0.6808362904199327
#   -51    51  0.507 0.809698150657846
#    52    51  0.460 0.9737760061548704
#    51   -51  0.507 1.2733538357582117
#     5     4  0.601 1.354273250650033
#    51    50  0.813 1.486539565298837
#     4     5  0.525 1.626848552386806
#   -52    51  0.476 1.7103183619022382
#    51    51  0.932 2.371321610115188
